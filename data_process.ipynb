# %%
import pickle
import os
import os.path as osp
import json
import numpy as np

# %%
def load_json(file_path):
    with open(file_path, "rb") as f:
        data = json.load(f)
        # logger.info(f"Loaded Json: {file_path}")
    return data


def load_pickle(file_path):
    with open(file_path, "rb") as f:
        data = pickle.load(f)
        # logger.info(f"Loaded Pickle: {file_path}")
    return data
def load_file(file_path):
    if file_path.endswith(".json"):
        return load_json(file_path)
    elif file_path.endswith(".pkl"):
        return load_pickle(file_path)
    else:
        raise ValueError(f"Unsupported file format: {file_path}")

# %%
raw_data_path = "/media/mtybilly/My Passport1/Program/GPL-Twitter/Data/TwitterData/raw"
raw_edges = load_file(osp.join(raw_data_path, "edges.json"))
keyword_dict = load_file(osp.join(raw_data_path, "keyword_embeddings.pkl"))
tweet_dict = load_file(osp.join(raw_data_path, "tweet_embeddings.pkl"))
user_dict = load_file(osp.join(raw_data_path, "user_embeddings.pkl"))
user_labels = load_file(osp.join(raw_data_path, "labels.json"))

# %%
raw_edges
# Out:
# [{'source_id': 'user_477',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_22398',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_15158',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_19855',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_2089',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_9468',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_2244',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_22686',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_9151',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_16095',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_3862',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_20039',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_8885',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_23059',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_21802',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_14055',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_1788',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_2378',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_13000',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_4462',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_15722',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_14101',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_19828',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_22841',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_26488',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_9301',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_9899',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2824'},
#  {'source_id': 'user_15633',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_22348',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_10343',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_6739',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_21714',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_23401',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_2670',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_17206',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_27746',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_12339',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_3577',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_20939',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_24608',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_10654',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1471'},
#  {'source_id': 'user_8065',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_18859',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_21288',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_10121',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_23434',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_9561',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_19411',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_3980',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_20206',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_9110',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_17499',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_4057',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_10881',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_3227',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_17681',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_13380',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_19887',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_14425',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_2679',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_2318',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_16531',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_27628',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_3448',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1680'},
#  {'source_id': 'user_1554',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1106'},
#  {'source_id': 'user_17370',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1106'},
#  {'source_id': 'user_3811',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1106'},
#  {'source_id': 'user_18142',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1106'},
#  {'source_id': 'user_12256',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_3821',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_9230',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_299',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_11861',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_11998',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_17047',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_23506',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_8556',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_4799',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_24340',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1125'},
#  {'source_id': 'user_27537',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1133'},
#  {'source_id': 'user_25462',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1133'},
#  {'source_id': 'user_18798',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1133'},
#  {'source_id': 'user_25894',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1133'},
#  {'source_id': 'user_2172',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1133'},
#  {'source_id': 'user_25703',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1133'},
#  {'source_id': 'user_1978',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1242',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_2044',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_13350',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_25152',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_20592',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_2097',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_2023',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_12538',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_419',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_26768',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1989',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1961',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1254',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_10081',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_2500',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_14961',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_2736',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1866',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_88',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1259',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_10899',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_19673',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_17266',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_23014',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1260',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_3562',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1251',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1245',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1238',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_3747',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_24006',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_25246',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_2041',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_2046',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1267',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_18316',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_27110',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_2476',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_26329',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1141'},
#  {'source_id': 'user_1989',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_19995',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_9062',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_4956',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_10420',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_4548',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_3656',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_16951',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_11500',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_1428',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_14979',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_15353',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_20548',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_20223',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_21757',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_8079',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_3383',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_7796',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1149'},
#  {'source_id': 'user_7860',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1151'},
#  {'source_id': 'user_2966',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1151'},
#  {'source_id': 'user_3551',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1151'},
#  {'source_id': 'user_4299',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1151'},
#  {'source_id': 'user_26881',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1151'},
#  {'source_id': 'user_16829',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1151'},
#  {'source_id': 'user_1641',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1151'},
#  {'source_id': 'user_23301',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_26047',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_5260',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_9933',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_21324',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_10969',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_2670',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_5006',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_15124',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_21433',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_20160',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_14401',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_19055',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_18136',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_27082',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_8157',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_5825',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_778',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_18220',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1152'},
#  {'source_id': 'user_1938',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_2787',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_483',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_1242',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_7784',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_17667',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_437',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_8104',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_2433',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_2703',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_1272',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2587'},
#  {'source_id': 'user_10687',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_26500',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_22502',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_8454',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_13200',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_8382',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_24205',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_2849',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_9518',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_10933',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_21565',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_15199',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_4568',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_11848',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_4503',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_26692',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_25725',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_14652',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_4603',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_16038',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_4683',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_7522',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_12771',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_17122',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_16212',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_13448',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_21858',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_6155',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_27859',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_5752',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_14322',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_21870',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_8331',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_2378',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_4295',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_5947',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_22582',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_10540',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_19410',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_15846',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_14988',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_27481',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_14101',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_8120',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_16943',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_18204',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_26399',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_26488',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_4793',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_25480',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1160'},
#  {'source_id': 'user_25568',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_1092',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_23530',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_13960',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_8046',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_25905',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_18213',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_15284',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_16311',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_25318',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_27045',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_11080',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_17508',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_20719',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_2590',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_10771',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_22162',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_15488',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_6872',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_3827',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_23667',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_12932',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_13519',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1163'},
#  {'source_id': 'user_12515',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_25202',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_26333',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_19259',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_21035',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_15127',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_7430',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_18559',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_26983',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_10580',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_26142',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_5371',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_21992',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_19485',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_18245',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_394',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_23253',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1175'},
#  {'source_id': 'user_24322',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_27596',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_20764',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_23784',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_13278',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_19255',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_9300',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_4121',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_23960',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_24533',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_23939',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_23457',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_14076',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_8575',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_23059',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_9986',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_13733',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_14055',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_26759',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_14088',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_23881',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_2763',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_26399',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_11882',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_15597',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_17436',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_3959',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_26244',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1179'},
#  {'source_id': 'user_2900',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1180'},
#  {'source_id': 'user_23302',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1180'},
#  {'source_id': 'user_7407',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1180'},
#  {'source_id': 'user_7368',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1180'},
#  {'source_id': 'user_6261',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1180'},
#  {'source_id': 'user_2350',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1180'},
#  {'source_id': 'user_9220',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1180'},
#  {'source_id': 'user_13166',
#   'relation': 'user-follower-user',
#   'target_id': 'user_724'},
#  {'source_id': 'user_16345',
#   'relation': 'user-follower-user',
#   'target_id': 'user_724'},
#  {'source_id': 'user_12936',
#   'relation': 'user-follower-user',
#   'target_id': 'user_724'},
#  {'source_id': 'user_2493',
#   'relation': 'user-follower-user',
#   'target_id': 'user_724'},
#  {'source_id': 'user_14925',
#   'relation': 'user-follower-user',
#   'target_id': 'user_724'},
#  {'source_id': 'user_24640',
#   'relation': 'user-follower-user',
#   'target_id': 'user_724'},
#  {'source_id': 'user_19022',
#   'relation': 'user-follower-user',
#   'target_id': 'user_724'},
#  {'source_id': 'user_4428',
#   'relation': 'user-follower-user',
#   'target_id': 'user_724'},
#  {'source_id': 'user_11393',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1186'},
#  {'source_id': 'user_1714',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1186'},
#  {'source_id': 'user_19165',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1186'},
#  {'source_id': 'user_11885',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1186'},
#  {'source_id': 'user_10693',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1186'},
#  {'source_id': 'user_25359',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_22419',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_19931',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_26248',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_2849',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_10985',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_2857',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_20070',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_5853',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_15805',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_19960',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_12638',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_22686',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_5186',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_4662',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_19199',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_3980',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_23059',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_15224',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_18279',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_5553',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_123',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_17920',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_16669',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_2646',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_9009',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_4179',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_4284',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_3892',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_14004',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1190'},
#  {'source_id': 'user_6368',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1192'},
#  {'source_id': 'user_5274',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1192'},
#  {'source_id': 'user_20646',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1192'},
#  {'source_id': 'user_2685',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1192'},
#  {'source_id': 'user_1573',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1192'},
#  {'source_id': 'user_6287',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1192'},
#  {'source_id': 'user_1068',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1192'},
#  {'source_id': 'user_17508',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1192'},
#  {'source_id': 'user_22533',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1198'},
#  {'source_id': 'user_18889',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1198'},
#  {'source_id': 'user_2373',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1198'},
#  {'source_id': 'user_733',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1198'},
#  {'source_id': 'user_19854',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1200'},
#  {'source_id': 'user_17173',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1200'},
#  {'source_id': 'user_1939',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1200'},
#  {'source_id': 'user_12972',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1200'},
#  {'source_id': 'user_12796',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1200'},
#  {'source_id': 'user_23386',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1200'},
#  {'source_id': 'user_3562',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1200'},
#  {'source_id': 'user_16549',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_24529',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_706',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_13190',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_1916',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_21339',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_649',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_1145',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_11483',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_10957',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_24718',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_6995',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1205'},
#  {'source_id': 'user_27039',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2103'},
#  {'source_id': 'user_2520',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2103'},
#  {'source_id': 'user_2068',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2103'},
#  {'source_id': 'user_25311',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2103'},
#  {'source_id': 'user_17812',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2103'},
#  {'source_id': 'user_1245',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2103'},
#  {'source_id': 'user_1238',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2103'},
#  {'source_id': 'user_16685',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1208'},
#  {'source_id': 'user_7589',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1208'},
#  {'source_id': 'user_340',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1208'},
#  {'source_id': 'user_5351',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1208'},
#  {'source_id': 'user_6983',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1208'},
#  {'source_id': 'user_24789',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1208'},
#  {'source_id': 'user_6528',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1208'},
#  {'source_id': 'user_16201',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1208'},
#  {'source_id': 'user_20470',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_5423',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_14360',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_17270',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_9641',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_5224',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_12397',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_13337',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_11944',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_2635',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_6603',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_13384',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_13096',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_8285',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_5342',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_17698',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_9840',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_2003',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_20052',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_22358',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_88',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_11466',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_25716',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_25739',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_1428',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_12297',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_15688',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_13775',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_24123',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_12971',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_9510',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_12403',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_11695',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_25638',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_4926',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_17839',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_5000',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_18420',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_17824',
#   'relation': 'user-follower-user',
#   'target_id': 'user_532'},
#  {'source_id': 'user_12559',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1218'},
#  {'source_id': 'user_1459',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1218'},
#  {'source_id': 'user_19394',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1218'},
#  {'source_id': 'user_690',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1218'},
#  {'source_id': 'user_1198',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1218'},
#  {'source_id': 'user_15741',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1218'},
#  {'source_id': 'user_6175',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1218'},
#  {'source_id': 'user_2523',
#   'relation': 'user-follower-user',
#   'target_id': 'user_973'},
#  {'source_id': 'user_21588',
#   'relation': 'user-follower-user',
#   'target_id': 'user_973'},
#  {'source_id': 'user_10420',
#   'relation': 'user-follower-user',
#   'target_id': 'user_973'},
#  {'source_id': 'user_18154',
#   'relation': 'user-follower-user',
#   'target_id': 'user_973'},
#  {'source_id': 'user_14052',
#   'relation': 'user-follower-user',
#   'target_id': 'user_973'},
#  {'source_id': 'user_3303',
#   'relation': 'user-follower-user',
#   'target_id': 'user_973'},
#  {'source_id': 'user_9002',
#   'relation': 'user-follower-user',
#   'target_id': 'user_973'},
#  {'source_id': 'user_27414',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1656'},
#  {'source_id': 'user_16601',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1656'},
#  {'source_id': 'user_1615',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1656'},
#  {'source_id': 'user_20549',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1656'},
#  {'source_id': 'user_20672',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1656'},
#  {'source_id': 'user_20049',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_9663',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_20598',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_3214',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_4650',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_5510',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_17699',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_18463',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_10349',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_7522',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_3231',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_24965',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_8995',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_11155',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_25815',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_21418',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_15792',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_3873',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_22770',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_15809',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_8726',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_3306',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_21792',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_16171',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_5825',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_8494',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_11951',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_2851',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_19564',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1225'},
#  {'source_id': 'user_20051',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_24321',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_22204',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_25389',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_27448',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_14804',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_1428',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_8929',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_8534',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_20501',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_17962',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_23371',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_25534',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_21023',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1229'},
#  {'source_id': 'user_3713',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_2070',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_20093',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_2068',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_419',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_2525',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_1961',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_2477',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_1252',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_1265',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_17457',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_1963',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_1259',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_1995',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_23088',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_17266',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_1369',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_1260',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1232'},
#  {'source_id': 'user_2526',
#   'relation': 'user-follower-user',
# ...
#  {'source_id': 'user_13253',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2160'},
#  {'source_id': 'user_2528',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2160'},
#  {'source_id': 'user_27541',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2290'},
#  {'source_id': 'user_1452',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2290'},
#  {'source_id': 'user_6757',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_8380',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_11934',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_15035',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_5061',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_13609',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_9518',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_18830',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_24569',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_23479',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_7334',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_3007',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_16893',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_22714',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_21246',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_17267',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_1876',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_15676',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_23515',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_8306',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_3730',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_10235',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_13947',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_24533',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_2749',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_17457',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_24391',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_9531',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_9330',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_26696',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_7209',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_26022',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_27312',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_2931',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_7336',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_15619',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_11322',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_19865',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_4445',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_9043',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_7827',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_25106',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_6826',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_6910',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_25368',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_24906',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_3837',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_20951',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_8667',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_15090',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_5617',
#   'relation': 'user-follower-user',
#   'target_id': 'user_559'},
#  {'source_id': 'user_4626',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_20817',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_7459',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_8424',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_1978',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_10914',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_14284',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_10031',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_2849',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_22854',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_4192',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_26025',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_27442',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_26594',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_23784',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_2654',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_6563',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_9887',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_16906',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_27235',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_13143',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_15351',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_3481',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_7304',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_2414',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_6145',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_24533',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_13373',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_3577',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_15114',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_26171',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_3980',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_17122',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_20039',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_19269',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_12669',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_6810',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_1855',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_2845',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_12883',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_18136',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_8493',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_14269',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_16124',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_22768',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_17920',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_23881',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_5746',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_1275',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_14874',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_19829',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_25605',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_6910',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_14101',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_2851',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_4961',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_24362',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_25477',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_18083',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_9899',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_15090',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_3892',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_22896',
#   'relation': 'user-follower-user',
#   'target_id': 'user_169'},
#  {'source_id': 'user_2801',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1623'},
#  {'source_id': 'user_9761',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1623'},
#  {'source_id': 'user_13454',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1623'},
#  {'source_id': 'user_23078',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1623'},
#  {'source_id': 'user_20373',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1623'},
#  {'source_id': 'user_5159',
#   'relation': 'user-follower-user',
#   'target_id': 'user_987'},
#  {'source_id': 'user_8260',
#   'relation': 'user-follower-user',
#   'target_id': 'user_987'},
#  {'source_id': 'user_2658',
#   'relation': 'user-follower-user',
#   'target_id': 'user_987'},
#  {'source_id': 'user_20108',
#   'relation': 'user-follower-user',
#   'target_id': 'user_987'},
#  {'source_id': 'user_18400',
#   'relation': 'user-follower-user',
#   'target_id': 'user_987'},
#  {'source_id': 'user_11206',
#   'relation': 'user-follower-user',
#   'target_id': 'user_987'},
#  {'source_id': 'user_17418',
#   'relation': 'user-follower-user',
#   'target_id': 'user_987'},
#  {'source_id': 'user_15563',
#   'relation': 'user-follower-user',
#   'target_id': 'user_987'},
#  {'source_id': 'user_12410',
#   'relation': 'user-follower-user',
#   'target_id': 'user_987'},
#  {'source_id': 'user_11465',
#   'relation': 'user-follower-user',
#   'target_id': 'user_987'},
#  {'source_id': 'user_11',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_15244',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_19400',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_14775',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_27908',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_13717',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_19531',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_19984',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_7082',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_14876',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_10711',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_18469',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_11504',
#   'relation': 'user-follower-user',
#   'target_id': 'user_1472'},
#  {'source_id': 'user_2328',
#   'relation': 'user-follower-user',
#   'target_id': 'user_901'},
#  {'source_id': 'user_24650',
#   'relation': 'user-follower-user',
#   'target_id': 'user_901'},
#  {'source_id': 'user_3182',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2364'},
#  {'source_id': 'user_17645',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2364'},
#  {'source_id': 'user_11194',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2364'},
#  {'source_id': 'user_19656',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2364'},
#  {'source_id': 'user_7396',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2364'},
#  {'source_id': 'user_682',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2364'},
#  {'source_id': 'user_7976',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2364'},
#  {'source_id': 'user_3651',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2364'},
#  {'source_id': 'user_2534',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2364'},
#  {'source_id': 'user_21400',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2364'},
#  {'source_id': 'user_1489',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_12005',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_17470',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_23116',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_12714',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_27844',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_3723',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_1610',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_23710',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_22584',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_4558',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_15084',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_22933',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  {'source_id': 'user_2193',
#   'relation': 'user-follower-user',
#   'target_id': 'user_2453'},
#  ...]

# %%
from easydict import EasyDict
from collections import defaultdict

# %%
relations_types = { edge["relation"] for edge in raw_edges }
relations_types
# Out:
# {'tweet-include-keyword',
#  'tweet-tag-keyword',
#  'user-engage-tweet',
#  'user-follower-user',
#  'user-following-user',
#  'user-post-tweet',
#  'user-profile-keyword'}

# %%
user_stat = {user_id: defaultdict(int) for user_id in user_labels.keys()}

# %%
for edge in raw_edges:
    source_id, relation, target_id = edge["source_id"], edge["relation"], edge["target_id"]
    if source_id.startswith("user_"):
        user_stat[source_id][relation] += 1
    if target_id.startswith("user_"):
        user_stat[target_id][relation] += 1

# %%
class_members = {label :[] for label in user_labels.values()}
for user_id, label in user_labels.items():
    class_members[label].append(user_id)

# %%
print({label: len(users) for label, users in class_members.items()})
# Out:
# {'Buyer': 2142, 'Related': 668, 'Seller': 627, 'Negative': 25402}

# %%
selected_users = {}
class_size = {}
for label in class_members:
    if label != "Negative":
        selected_users[label] = class_members[label]
    else:
        selected_users[label] = np.random.choice(class_members[label], len(class_members[label]) //3 , replace=False)

# %%
print({label: len(users) for label, users in selected_users.items()})
# Out:
# {'Buyer': 2142, 'Related': 668, 'Seller': 627, 'Negative': 8467}
